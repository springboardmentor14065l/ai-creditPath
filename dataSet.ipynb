# %% [markdown]
# <a href="https://colab.research.google.com/github/springboardmentor14065l/ai-creditPath/blob/Mahalakshmi-creditPathAI/dataSet.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install kagglehub

# %%
import kagglehub
import os

# Download dataset
path = kagglehub.dataset_download("anggundwilestari/home-credit")

print("Path to dataset files:", path)

# List downloaded files
print(os.listdir(path))
# Out:
# ...
# 100%|██████████| 702M/702M [00:09<00:00, 81.1MB/s]
# Extracting files...
# Path to dataset files: /root/.cache/kagglehub/datasets/anggundwilestari/home-credit/versions/4
# ['HC_sample_submission.csv', 'Model ML_Logisctic Regression.ipynb', 'Model ML_XGBoost.ipynb', 'HC_installments_payments.csv', 'HomeCredit_columns_description.csv', 'HC_bureau.csv', 'HC_application_train.csv', 'HC_POS_CASH_balance.csv', 'Model ML_Random Forest.ipynb', 'Preprocessing_merged.ipynb', 'HC_previous_application.csv', 'EDA_merged.ipynb', 'Model_LGBM.ipynb', 'HC_bureau_balance.csv', 'HC_credit_card_balance.csv']

# %%
import pandas as pd

file_path = "/root/.cache/kagglehub/datasets/anggundwilestari/home-credit/versions/4/HC_application_train.csv"

df = pd.read_csv(file_path)

print(df.shape)
df.head()
df.tail()
# Out:
# (307511, 122)
#         SK_ID_CURR  TARGET NAME_CONTRACT_TYPE CODE_GENDER FLAG_OWN_CAR  \
# 307506      456251       0         Cash loans           M            N
# 307507      456252       0         Cash loans           F            N
# 307508      456253       0         Cash loans           F            N
# 307509      456254       1         Cash loans           F            N
# 307510      456255       0         Cash loans           F            N
#
#        FLAG_OWN_REALTY  CNT_CHILDREN  AMT_INCOME_TOTAL  AMT_CREDIT  \
# 307506               N             0          157500.0    254700.0
# 307507               Y             0           72000.0    269550.0
# 307508               Y             0          153000.0    677664.0
# 307509               Y             0          171000.0    370107.0
# 307510               N             0          157500.0    675000.0
#
#         AMT_ANNUITY  ...  FLAG_DOCUMENT_18 FLAG_DOCUMENT_19 FLAG_DOCUMENT_20  \
# ...
